# %%
import pandas as pd
import numpy as np
import sys, os

# %%
from script import deribit_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-56ea2fdb7778> in <module>
# ----> 1 from script import deribit_data
#
# ModuleNotFoundError: No module named 'script'
